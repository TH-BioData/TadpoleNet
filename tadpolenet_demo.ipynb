# %%
# If we are in Google Colab, mount Google Drive and install the package.
from google.colab import drive
drive.mount('/content/drive')

# !pip install /content/drive/MyDrive/TadpoleNet_package/TadpoleNet_package.zip # Modify the path if necessary. It is NOT necessary to unzip the file.

import tadpole_seg as tps
import pandas as pd
# Out:
# Mounted at /content/drive
# Processing ./drive/MyDrive/TadpoleNet_package/TadpoleNet_package.zip
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.0/224.0 kB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 66.8 MB/s eta 0:00:00
# ...
#   Created wheel for tadpole-seg: filename=tadpole_seg-0.2.0-py3-none-any.whl size=23394992 sha256=7c4740392071c4cb0b58f50608a2d218975475341f7f4e4795bbc15d3b13a705
# ...

# %%
results = tps.segment_tadpole(
    scale_px_per_cm=317.4291,                         # px/cm
    input_path="/content/DSCN7469.JPG",   # image or folder
    output_dir="/content/",
    return_visuals=True,   # with plots
    save_outputs=False,      # don't save *_pred.png and *_overlay.jpg
)
# Out:
# Done. Processed 1 image(s). Output dir: (not saved)

# %%
results = tps.segment_tadpole(
    scale_px_per_cm=317.4291,                         # px/cm
    input_path="/content/DSCN7469.JPG",   # image or folder
    output_dir="/content/",
    return_visuals=False,   # without plots
    save_outputs=True,      # save *_pred.png and *_overlay.jpg
)
# Out:
# Done. Processed 1 image(s). Output dir: /content

# %%
results = tps.segment_tadpole(
    scale_px_per_cm=317.4291,                         # px/cm
    input_path="/content/drive/MyDrive/folder",   # folder
    output_dir="/content/drive/MyDrive/folder",
    return_visuals=True,   # with plots
    save_outputs=True,      # save *_pred.png and *_overlay.jpg
)
# Out:
# Done. Processed 4 image(s). Output dir: /content/drive/MyDrive/folder
